# %% [markdown]
# <a href="https://colab.research.google.com/github/NishanChy733689/Tip_Analysis/blob/main/Tips_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
var=sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
var.isnull().values.any()
# Out:
# False

# %%
sns.heatmap(var.corr(),annot=True)
# Out:
# <ipython-input-4-7cdca33f6467>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(var.corr(),annot=True)
# <Axes: >

# %%
sns.boxplot(x='time',y='total_bill',data=var)
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# **Most of the tips come from the dinner**

# %%
sns.boxplot(x='time',y='total_bill',data=var,hue='sex')
# Out:
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# **Females pay less tip than male in the dinner**

# %%
sns.scatterplot(x='size',y='total_bill',data=var)
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.histplot(data=var,x='tip',kde=True,element='step')
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %% [markdown]
# Most of the tips are between 2 to 4 dollars

# %%
sns.scatterplot(data=var,x='size',y='tip')
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.barplot(data=var,x='size',y='tip',ci=-0)
# Out:
# <ipython-input-10-5b2461244c08>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.barplot(data=var,x='size',y='tip',ci=-0)
# <Axes: xlabel='size', ylabel='tip'>

# %%
sns.lineplot(data=var,x='size',y='tip',ci=-0)
# Out:
# <ipython-input-11-04dc87b3d648>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 0)` for the same effect.
#
#   sns.lineplot(data=var,x='size',y='tip',ci=-0)
# <Axes: xlabel='size', ylabel='tip'>

# %% [markdown]
# **The tip increases as the food or order size increases**

# %%
sns.kdeplot(data=var,x='tip',y='total_bill',hue='smoker',dodge=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py:1185: UserWarning: The following kwargs were not used by contour: 'dodge'
#   cset = contour_func(
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.boxplot(data=var,x='day',y='total_bill',hue='smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=var,x='day',y='total_bill',hue='smoker',errorbar=('ci', 0))
plt.show()

# %% [markdown]
# Most of the bills are paid by smokers on sunday

# %%
smoker=var.smoker.value_counts().to_dict()

# %%
smoker['Yes']
# Out:
# 93

# %%
smoker['No']
# Out:
# 151

# %%
sns.barplot(x=['No','Yes'],y=[ smoker['No'],smoker['Yes']  ] )
# Out:
# <Axes: >

# %% [markdown]
# Although most of the customers do not smoke but the smokers pay more bills
